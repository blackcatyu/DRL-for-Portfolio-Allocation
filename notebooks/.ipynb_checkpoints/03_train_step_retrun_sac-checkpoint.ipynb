# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import importlib
import matplotlib.pyplot as plt

import env.trading_env as te
import features.feature_engineering as fe
importlib.reload(te)
importlib.reload(fe)

from stable_baselines3 import SAC
from stable_baselines3.common.callbacks import BaseCallback

# %%
# Read data
df = pd.read_excel('../data/data.xlsx', skiprows=6, header=0)
df.columns = ['date', 'gold', 'silver', 'copper']
df = df[pd.to_datetime(df['date'], errors='coerce').notna()]
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# %%
# Feature engineering
features_final = fe.build_features(df)

# Split
train = features_final[features_final.index <= '2023-12-31']
test = features_final[features_final.index >= '2024-01-01']
price_train = df[df.index.isin(train.index)]
price_test = df[df.index.isin(test.index)]

print(f"Train: {len(train)}days, Test: {len(test)}days")
# Out:
# Train: 2592days, Test: 485days

# %%
class RewardCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []
        self.current_rewards = []
    
    def _on_step(self):
        reward = self.locals['rewards'][0]
        self.current_rewards.append(reward)
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(sum(self.current_rewards))
            self.current_rewards = []
        return True

# Initialising the environment
train_env = te.MetalTradingEnv(train, price_train)
callback_sac500k = RewardCallback()

model_sac500k = SAC(
    "MlpPolicy",
    train_env,
    learning_rate=3e-4,
    batch_size=256,
    buffer_size=100_000,
    learning_starts=1000,
    gamma=0.99,
    verbose=0
)

model_sac500k.learn(total_timesteps=500_000, callback=callback_sac500k)
print("finish training")



# plot
plt.figure(figsize=(12, 4))
plt.plot(callback_sac500k.episode_rewards)
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("SAC Training Reward Curve (500k steps)")
plt.axhline(y=0, color='r', linestyle='--', alpha=0.5)
plt.show()

print(f"Average reward for the last 10 episodes: {sum(callback_sac500k.episode_rewards[-10:])/10:.4f}")
# Out:
# finish training
# Average reward for the last 10 episodes: 11.9232

# %%
model_sac500k.save("../agents/sac_step_500k")
np.save("../agents/sac_step_500k", callback_sac500k.episode_rewards)

# %% [markdown]
# continue training

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import importlib
import matplotlib.pyplot as plt

import env.trading_env as te
import features.feature_engineering as fe
importlib.reload(te)
importlib.reload(fe)

from stable_baselines3 import SAC
from stable_baselines3.common.callbacks import BaseCallback

# Read data
df = pd.read_excel('../data/data.xlsx', skiprows=6, header=0)
df.columns = ['date', 'gold', 'silver', 'copper']
df = df[pd.to_datetime(df['date'], errors='coerce').notna()]
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# Feature engineering
features_final = fe.build_features(df)

# Split
train = features_final[features_final.index <= '2023-12-31']
test = features_final[features_final.index >= '2024-01-01']
price_train = df[df.index.isin(train.index)]
price_test = df[df.index.isin(test.index)]

print(f"Train: {len(train)}days, Test: {len(test)}days")

train_env = te.MetalTradingEnv(train, price_train)
model_sac1m = SAC.load("../agents/sac_step_500k", env=train_env)
# Out:
# Train: 2592days, Test: 485days

# %%
# Continue training for 500,000 steps (to reach a total of 1 million)
class RewardCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_rewards = []
        self.current_rewards = []
    
    def _on_step(self):
        reward = self.locals['rewards'][0]
        self.current_rewards.append(reward)
        
        if self.locals['dones'][0]:
            self.episode_rewards.append(sum(self.current_rewards))
            self.current_rewards = []
        return True

# New callback records for subsequent training
callback_sac_1m = RewardCallback()

model_sac1m.learn(total_timesteps=500_000, callback=callback_sac_1m, reset_num_timesteps=False)
print("Training completed")

# plot
plt.figure(figsize=(12, 4))
plt.plot(callback_sac_1m.episode_rewards)
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("SAC Training Reward Curve (500k-1M steps)")
plt.axhline(y=0, color='r', linestyle='--', alpha=0.5)
plt.show()

print(f"Average reward for the last 10 episodes: {sum(callback_sac_1m.episode_rewards[-10:])/10:.4f}")
# Out:
# Training completed
# Average reward for the last 10 episodes: 12.7665

# %%
# save
model_sac1m.save("../agents/sac_step_1m")
np.save("../agents/sac_rewards_1m.npy", callback_sac_1m.episode_rewards)

# %%
train_env = te.MetalTradingEnv(train, price_train)
model_sac700k = SAC.load("../agents/sac_step_500k", env=train_env)

callback_sac_700k = RewardCallback()

model_sac700k.learn(total_timesteps=200_000, callback=callback_sac_700k, reset_num_timesteps=False)
print("Training completed")

# plot
plt.figure(figsize=(12, 4))
plt.plot(callback_sac_700k.episode_rewards)
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("SAC Training Reward Curve (500k-700k steps)")
plt.axhline(y=0, color='r', linestyle='--', alpha=0.5)
plt.show()

print(f"Average reward for the last 10 episodes: {sum(callback_sac_700k.episode_rewards[-10:])/10:.4f}")
# Out:
# Training completed
# Average reward for the last 10 episodes: 12.3713

# %%
# save
model_sac700k.save("../agents/sac_step_700k")
np.save("../agents/sac_rewards_700k.npy", callback_sac_1m.episode_rewards)

# %%
#actionlog
